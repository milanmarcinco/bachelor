# %%
import json, random
from openai import OpenAI
from dotenv import dotenv_values

from typing import List

# %%
env = dotenv_values()

API_KEY = env['OPENAI_API_KEY']
MODEL = env['OPENAI_MODEL']

summaries_filename = "01_summaries.json"
queries_filename = "02_queries.json"

# %%
client = OpenAI(api_key=API_KEY)

# %%
# Define a helper function to extract the only key-value pair from a dictionary no matter what the key is.

def get_value_from_dict(dict):
  return dict[list(dict.keys())[0]]

# %% [markdown]
# # Pipeline

# %%
# Create an assistant
assistant = client.beta.assistants.create(
    name="asst_bachelor_queries",
    instructions="You are a helpful assistant that generates keyword-based, Google-like user search queries that retrieve a subset of a specified list of documents.",
    response_format={"type": "json_object"},
    temperature=0.7,
    model=MODEL
)

# %%
prompt = "Generate 10 English user search queries that would retrieve a subset of an arbitrary size from the list of documents provided above. Each object contains a document id, title, and a short summary that describes its contents. Return a JSON array of strings, where each string represents a single query. The queries should be keyword-based and should resemble Google search queries of various levels of specificity."

prompt = "Generate 10 English user search queries that would retrieve a subset of an arbitrary size from the list of documents provided above. Each object contains a document id, title, and a short summary that describes its contents. Use advanced, domain-specific keywords directly from the document summaries to craft the queries. Return a JSON array of strings, where each string represents a single query. The queries should be 3 to 5 words long, keyword-based and should resemble Google search queries."

# %%
# Load summaries, leaving out those with None/null value

BATCH_SIZE = 40

with open(summaries_filename, "r") as f:
    summaries = json.load(f)

summaries = [s for s in summaries if s["summary"] is not None]
batches = [summaries[i:i + BATCH_SIZE]
           for i in range(0, len(summaries), BATCH_SIZE)]

# %%
def get_queries_for_batch(batch):
    # Create a single thread for this entire step
    thread = client.beta.threads.create()

    client.beta.threads.messages.create(
        thread_id=thread.id,
        content=[
            {
                "type": "text",
                "text": json.dumps(
                    batch,
                    indent=2,
                    ensure_ascii=False
                )
            },
            {
                "type": "text",
                "text": prompt
            }
        ],
        role="user"
    )

    run = client.beta.threads.runs.create_and_poll(
        thread_id=thread.id,
        assistant_id=assistant.id,
    )

    print(run)

    if run.status != "completed":
        raise Exception("Run failed:", run.status)

    messages_cursor = client.beta.threads.messages.list(
        thread.id,
        limit=1,
        order="desc"
    )

    message = [message for message in messages_cursor][0]
    response_content = message.content[0].text.value
    response_dict = json.loads(response_content)
    results: List[str] = get_value_from_dict(response_dict)

    client.beta.threads.delete(thread.id)

    return results

# %%
# Generate queries for each batch of summaries,
# repeat 3 times with shuffling.

queries = []

for _ in range(5):
    random.shuffle(batches)

    for batch in batches:
        batch_queries = get_queries_for_batch(batch)
        queries.extend(batch_queries)

        print(json.dumps(
            batch_queries,
            indent=2,
            ensure_ascii=False
        ))
# Out:
# Run(id='run_6QR4vLAnUl2qU2A3au2WQLMv', assistant_id='asst_SreO4Pk8aTxVftJmDMm2ybHM', cancelled_at=None, completed_at=1736190403, created_at=1736190399, expires_at=None, failed_at=None, incomplete_details=None, instructions='You are a helpful assistant that generates keyword-based, Google-like user search queries that retrieve a subset of a specified list of documents.', last_error=None, max_completion_tokens=None, max_prompt_tokens=None, metadata={}, model='gpt-4o', object='thread.run', parallel_tool_calls=True, required_action=None, response_format=ResponseFormatJSONObject(type='json_object'), started_at=1736190400, status='completed', thread_id='thread_BssWHFKNBqC1Rtjk0W08hID8', tool_choice='auto', tools=[], truncation_strategy=TruncationStrategy(type='auto', last_messages=None), usage=Usage(completion_tokens=92, prompt_tokens=12892, total_tokens=12984, prompt_token_details={'cached_tokens': 0}), temperature=0.7, top_p=1.0, tool_resources={})
# [
#   "marine protected areas Arctic",
#   "Russian IT capitalism networks",
#   "VLBI radio astronomy techniques",
#   "academic book digital age",
#   "Venezuelan grassroots oil politics",
#   "Pentecostalism witchcraft Africa",
#   "anti-vivisection British medicine",
#   "Norway white-collar crime",
#   "youth crisis Britain",
#   "Vietnam food anxiety globalization"
# ]
# Run(id='run_CZ3JfVgegESugJyVDnzrH55B', assistant_id='asst_SreO4Pk8aTxVftJmDMm2ybHM', cancelled_at=None, completed_at=1736190419, created_at=1736190412, expires_at=None, failed_at=None, incomplete_details=None, instructions='You are a helpful assistant that generates keyword-based, Google-like user search queries that retrieve a subset of a specified list of documents.', last_error=None, max_completion_tokens=None, max_prompt_tokens=None, metadata={}, model='gpt-4o', object='thread.run', parallel_tool_calls=True, required_action=None, response_format=ResponseFormatJSONObject(type='json_object'), started_at=1736190416, status='completed', thread_id='thread_Pw3f5wFgNWytrw2dIDpnXZAF', tool_choice='auto', tools=[], truncation_strategy=TruncationStrategy(type='auto', last_messages=None), usage=Usage(completion_tokens=94, prompt_tokens=13337, total_tokens=13431, prompt_token_details={'cached_tokens': 0}), temperature=0.7, top_p=1.0, tool_resources={})
# [
#   "Twitter research methodologies challenges",
#   "X-ray contrast media evolution",
#   "Distributed denial-of-service blockchain",
#   "Iskandar Malaysia low carbon",
#   "Philosophy of mathematics education",
#   "Butterfly mimicry population dynamics",
#   "Islamic bioethics medical practices",
#   "Nature-based urban climate solutions",
#   "Microfinance sustainability social outreach",
#   "Sago palm food security"
# ]
# Run(id='run_yAROPjlbkCQiqcs01121TQOB', assistant_id='asst_SreO4Pk8aTxVftJmDMm2ybHM', cancelled_at=None, completed_at=1736190433, created_at=1736190429, expires_at=None, failed_at=None, incomplete_details=None, instructions='You are a helpful assistant that generates keyword-based, Google-like user search queries that retrieve a subset of a specified list of documents.', last_error=None, max_completion_tokens=None, max_prompt_tokens=None, metadata={}, model='gpt-4o', object='thread.run', parallel_tool_calls=True, required_action=None, response_format=ResponseFormatJSONObject(type='json_object'), started_at=1736190430, status='completed', thread_id='thread_axShIKJjpYYAPXstBoEpc90z', tool_choice='auto', tools=[], truncation_strategy=TruncationStrategy(type='auto', last_messages=None), usage=Usage(completion_tokens=88, prompt_tokens=12676, total_tokens=12764, prompt_token_details={'cached_tokens': 0}), temperature=0.7, top_p=1.0, tool_resources={})
# [
#   "agile methodology scrum framework",
#   "personality traits team performance",
#   "data science human-centric AI",
#   "parallel entrepreneurship Africa",
#   "environmental governance Baltic Sea",
#   "endoprothesenversorgung Germany",
#   "saving investment Latin America",
#   "Ada Lovelace computing history",
#   "agricultural residue burning Punjab",
#   "production technology advancements"
# ]
# Run(id='run_fL3m7Xr8dybLeX674Xk8cohl', assistant_id='asst_SreO4Pk8aTxVftJmDMm2ybHM', cancelled_at=None, completed_at=1736190442, created_at=1736190438, expires_at=None, failed_at=None, incomplete_details=None, instructions='You are a helpful assistant that generates keyword-based, Google-like user search queries that retrieve a subset of a specified list of documents.', last_error=None, max_completion_tokens=None, max_prompt_tokens=None, metadata={}, model='gpt-4o', object='thread.run', parallel_tool_calls=True, required_action=None, response_format=ResponseFormatJSONObject(type='json_object'), started_at=1736190439, status='completed', thread_id='thread_d5NLp6XQix7cCnCfse4V2oqH', tool_choice='auto', tools=[], truncation_strategy=TruncationStrategy(type='auto', last_messages=None), usage=Usage(completion_tokens=81, prompt_tokens=15336, total_tokens=15417, prompt_token_details={'cached_tokens': 0}), temperature=0.7, top_p=1.0, tool_resources={})
# [
#   "quantum computing fundamentals",
#   "creative commons licensing guide",
#   "blockchain technology overview",
#   "R programming functional concepts",
#   "multiagent systems and agents",
#   "information retrieval methodologies",
#   "risk analysis in R",
#   "digital currencies blockchain",
#   "object-oriented programming C++",
#   "mathematical logic proofs"
# ]
# Run(id='run_hNhMzgzRg9tx1Li3cWe3pauY', assistant_id='asst_SreO4Pk8aTxVftJmDMm2ybHM', cancelled_at=None, completed_at=1736190455, created_at=1736190448, expires_at=None, failed_at=None, incomplete_details=None, instructions='You are a helpful assistant that generates keyword-based, Google-like user search queries that retrieve a subset of a specified list of documents.', last_error=None, max_completion_tokens=None, max_prompt_tokens=None, metadata={}, model='gpt-4o', object='thread.run', parallel_tool_calls=True, required_action=None, response_format=ResponseFormatJSONObject(type='json_object'), started_at=1736190450, status='completed', thread_id='thread_FnWwTMoEDxGkCm7Pn53ifa2V', tool_choice='auto', tools=[], truncation_strategy=TruncationStrategy(type='auto', last_messages=None), usage=Usage(completion_tokens=97, prompt_tokens=11586, total_tokens=11683, prompt_token_details={'cached_tokens': 0}), temperature=0.7, top_p=1.0, tool_resources={})
# [
#   "autonomous systems trustworthiness motivation",
#   "Albertine Statute Italian Unification",
#   "globalization science curricula TIMSS",
#   "Freiwilligensurvey freiwilliges Engagement Deutschland",
#   "CAADP agricultural policy Malawi",
#   "mobility older adults Germany",
#   "self-harm socio-economic challenges",
#   "rockburst precursor information",
#   "teaching tolerance globalization",
#   "European identity student perceptions"
# ]
# Run(id='run_TMXEjtpdt8bw7KZiCieBX5Lr', assistant_id='asst_SreO4Pk8aTxVftJmDMm2ybHM', cancelled_at=None, completed_at=1736190463, created_at=1736190460, expires_at=None, failed_at=None, incomplete_details=None, instructions='You are a helpful assistant that generates keyword-based, Google-like user search queries that retrieve a subset of a specified list of documents.', last_error=None, max_completion_tokens=None, max_prompt_tokens=None, metadata={}, model='gpt-4o', object='thread.run', parallel_tool_calls=True, required_action=None, response_format=ResponseFormatJSONObject(type='json_object'), started_at=1736190461, status='completed', thread_id='thread_ugUEb5OrFBOwJ1Kp8q2oV9ys', tool_choice='auto', tools=[], truncation_strategy=TruncationStrategy(type='auto', last_messages=None), usage=Usage(completion_tokens=87, prompt_tokens=12658, total_tokens=12745, prompt_token_details={'cached_tokens': 0}), temperature=0.7, top_p=1.0, tool_resources={})
# [
#   "food sovereignty and globalization",
#   "autonomous mobility urban transport",
#   "ethical implications drone regulations",
#   "hydrogen production and serpentinization",
#   "social innovations urban governance",
#   "FRAND commitments patent licensing",
#   "quantum mechanics deterministic chaos",
#   "shadow economy regulatory challenges",
#   "nuclear accident marine contamination",
#   "digital sovereignty and autonomy"
# ]
# Run(id='run_dWReSN3O2zyFLrEE86yiiZQN', assistant_id='asst_SreO4Pk8aTxVftJmDMm2ybHM', cancelled_at=None, completed_at=1736190474, created_at=1736190471, expires_at=None, failed_at=None, incomplete_details=None, instructions='You are a helpful assistant that generates keyword-based, Google-like user search queries that retrieve a subset of a specified list of documents.', last_error=None, max_completion_tokens=None, max_prompt_tokens=None, metadata={}, model='gpt-4o', object='thread.run', parallel_tool_calls=True, required_action=None, response_format=ResponseFormatJSONObject(type='json_object'), started_at=1736190472, status='completed', thread_id='thread_I2ehRHgicpt2miiviqkYMdJ7', tool_choice='auto', tools=[], truncation_strategy=TruncationStrategy(type='auto', last_messages=None), usage=Usage(completion_tokens=98, prompt_tokens=12670, total_tokens=12768, prompt_token_details={'cached_tokens': 0}), temperature=0.7, top_p=1.0, tool_resources={})
# [
#   "Cyber-Physical Systems emergent behaviors",
#   "Electoral College reform proposal",
#   "Georgia economic reforms 2004-2012",
#   "International healthcare voluntarism NHS",
#   "Low-carbon society vision 2050",
#   "Household carbon emissions drivers",
#   "Haptic feedback in music",
#   "Jordan River ecological restoration",
#   "Community museums cultural identity",
#   "Sustainable peri-urban development"
# ]
# Run(id='run_Bo5WU7n82S0b40Qc6uQTBdI0', assistant_id='asst_SreO4Pk8aTxVftJmDMm2ybHM', cancelled_at=None, completed_at=1736190484, created_at=1736190479, expires_at=None, failed_at=None, incomplete_details=None, instructions='You are a helpful assistant that generates keyword-based, Google-like user search queries that retrieve a subset of a specified list of documents.', last_error=None, max_completion_tokens=None, max_prompt_tokens=None, metadata={}, model='gpt-4o', object='thread.run', parallel_tool_calls=True, required_action=None, response_format=ResponseFormatJSONObject(type='json_object'), started_at=1736190481, status='completed', thread_id='thread_xpwrjLu5mx9Kfb9fxjllCUR7', tool_choice='auto', tools=[], truncation_strategy=TruncationStrategy(type='auto', last_messages=None), usage=Usage(completion_tokens=97, prompt_tokens=12115, total_tokens=12212, prompt_token_details={'cached_tokens': 0}), temperature=0.7, top_p=1.0, tool_resources={})
# [
#   "execution blood ritual Europe",
#   "posthumous harm and redemption",
#   "wave energy conversion technologies",
#   "male psychological disorders Britain",
#   "WiFi human activity recognition",
#   "chlorpyrifos ecological risk assessment",
#   "FSolidM Ethereum smart contracts",
#   "Hagedorn temperature quark-gluon plasma",
#   "nuclear transmutation waste disposal",
#   "autism education employment rights"
# ]
# Run(id='run_sHuRVh6Q4fsZLiCoeV93wMDh', assistant_id='asst_SreO4Pk8aTxVftJmDMm2ybHM', cancelled_at=None, completed_at=1736190497, created_at=1736190492, expires_at=None, failed_at=None, incomplete_details=None, instructions='You are a helpful assistant that generates keyword-based, Google-like user search queries that retrieve a subset of a specified list of documents.', last_error=None, max_completion_tokens=None, max_prompt_tokens=None, metadata={}, model='gpt-4o', object='thread.run', parallel_tool_calls=True, required_action=None, response_format=ResponseFormatJSONObject(type='json_object'), started_at=1736190493, status='completed', thread_id='thread_8k3Momcrb4CWFgghiMl0jA44', tool_choice='auto', tools=[], truncation_strategy=TruncationStrategy(type='auto', last_messages=None), usage=Usage(completion_tokens=106, prompt_tokens=12280, total_tokens=12386, prompt_token_details={'cached_tokens': 0}), temperature=0.7, top_p=1.0, tool_resources={})
# [
#   "mathematics education self-efficacy beliefs",
#   "nanoinformatics grain boundary engineering",
#   "rewilding European landscapes conservation",
#   "quantum optics structured light fields",
#   "semiotics mathematical visualization diagrams",
#   "satellite data environmental policy",
#   "aquaculture wind farms co-location",
#   "cosmic ray neutron sensing agriculture",
#   "cross-border migration family dynamics",
#   "CRISPR-Cas9 Duchenne muscular dystrophy"
# ]
# Run(id='run_mLEqCuvCqNon2LGo0n5meQg2', assistant_id='asst_SreO4Pk8aTxVftJmDMm2ybHM', cancelled_at=None, completed_at=1736190507, created_at=1736190503, expires_at=None, failed_at=None, incomplete_details=None, instructions='You are a helpful assistant that generates keyword-based, Google-like user search queries that retrieve a subset of a specified list of documents.', last_error=None, max_completion_tokens=None, max_prompt_tokens=None, metadata={}, model='gpt-4o', object='thread.run', parallel_tool_calls=True, required_action=None, response_format=ResponseFormatJSONObject(type='json_object'), started_at=1736190504, status='completed', thread_id='thread_SXRRAcZq0fOmC5MXDzXa7DIX', tool_choice='auto', tools=[], truncation_strategy=TruncationStrategy(type='auto', last_messages=None), usage=Usage(completion_tokens=91, prompt_tokens=12780, total_tokens=12871, prompt_token_details={'cached_tokens': 0}), temperature=0.7, top_p=1.0, tool_resources={})
# [
#   "Freshwater governance innovative approaches",
#   "Migration patterns EU crisis",
#   "Subject-Oriented Business Process Management",
#   "Protected areas climate change adaptation",
#   "Lag compensation cloud gaming",
#   "Conservation of bats Anthropocene",
#   "Climate Smart Agriculture resilience",
#   "Present bias planning incentives",
#   "Tuberculosis epidemiology treatment strategies",
#   "Non-custodial sanctions Europe"
# ]
# Run(id='run_Na0qDp9SvH6qnQuK8UoPXHyi', assistant_id='asst_SreO4Pk8aTxVftJmDMm2ybHM', cancelled_at=None, completed_at=1736190520, created_at=1736190513, expires_at=None, failed_at=None, incomplete_details=None, instructions='You are a helpful assistant that generates keyword-based, Google-like user search queries that retrieve a subset of a specified list of documents.', last_error=None, max_completion_tokens=None, max_prompt_tokens=None, metadata={}, model='gpt-4o', object='thread.run', parallel_tool_calls=True, required_action=None, response_format=ResponseFormatJSONObject(type='json_object'), started_at=1736190514, status='completed', thread_id='thread_a1bLn49HRRDl98W5H0JlcVL3', tool_choice='auto', tools=[], truncation_strategy=TruncationStrategy(type='auto', last_messages=None), usage=Usage(completion_tokens=91, prompt_tokens=12115, total_tokens=12206, prompt_token_details={'cached_tokens': 0}), temperature=0.7, top_p=1.0, tool_resources={})
# [
#   "execution blood consumption rituals",
#   "posthumous harm and redemption",
#   "male psychological disorders Britain",
#   "Alzheimer's disease life-writing",
#   "charged particle beam emittance",
#   "wave energy conversion technologies",
#   "residential segregation measurement methods",
#   "biodiversity citizen science networks",
#   "social sciences in resource management",
#   "moral luck and free action"
# ]
# Run(id='run_roRSytz2hoqfpYAYGcQYmG4F', assistant_id='asst_SreO4Pk8aTxVftJmDMm2ybHM', cancelled_at=None, completed_at=1736190528, created_at=1736190524, expires_at=None, failed_at=None, incomplete_details=None, instructions='You are a helpful assistant that generates keyword-based, Google-like user search queries that retrieve a subset of a specified list of documents.', last_error=None, max_completion_tokens=None, max_prompt_tokens=None, metadata={}, model='gpt-4o', object='thread.run', parallel_tool_calls=True, required_action=None, response_format=ResponseFormatJSONObject(type='json_object'), started_at=1736190525, status='completed', thread_id='thread_9GL5zJZvtBUiLUpqqfQtOaea', tool_choice='auto', tools=[], truncation_strategy=TruncationStrategy(type='auto', last_messages=None), usage=Usage(completion_tokens=96, prompt_tokens=12670, total_tokens=12766, prompt_token_details={'cached_tokens': 0}), temperature=0.7, top_p=1.0, tool_resources={})
# [
#   "Cyber-Physical Systems unpredictability",
#   "Electoral College reform proposals",
#   "Georgia economic reforms 2004-2012",
#   "NHS international volunteering challenges",
#   "Platinum Society sustainable future",
#   "Household carbon emissions determinants",
#   "Musical Haptics tactile feedback",
#   "Jordan Valley ecological restoration",
#   "Community museums cultural identity",
#   "Peri-urban development sustainability"
# ]
# Run(id='run_tBrQUerO2xkujQGowWhZKVSO', assistant_id='asst_SreO4Pk8aTxVftJmDMm2ybHM', cancelled_at=None, completed_at=1736190538, created_at=1736190534, expires_at=None, failed_at=None, incomplete_details=None, instructions='You are a helpful assistant that generates keyword-based, Google-like user search queries that retrieve a subset of a specified list of documents.', last_error=None, max_completion_tokens=None, max_prompt_tokens=None, metadata={}, model='gpt-4o', object='thread.run', parallel_tool_calls=True, required_action=None, response_format=ResponseFormatJSONObject(type='json_object'), started_at=1736190535, status='completed', thread_id='thread_EFyPWtV4b1DeIsDI9yyciXN1', tool_choice='auto', tools=[], truncation_strategy=TruncationStrategy(type='auto', last_messages=None), usage=Usage(completion_tokens=100, prompt_tokens=11586, total_tokens=11686, prompt_token_details={'cached_tokens': 0}), temperature=0.7, top_p=1.0, tool_resources={})
# [
#   "rockburst precursor information",
#   "Italian Unification constitutionalization",
#   "self-harm socio-economic challenges",
#   "globalization science curricula TIMSS",
#   "asylum care nineteenth-century Ireland",
#   "civic knowledge IEA ICCS 2016",
#   "autonomous systems computational motivation",
#   "glycoprotein analysis nanotechnology",
#   "migration gender social justice",
#   "ocean-atmosphere greenhouse gases"
# ]
# Run(id='run_5haysBkDsm6OF7tenwy4sjE0', assistant_id='asst_SreO4Pk8aTxVftJmDMm2ybHM', cancelled_at=None, completed_at=1736190547, created_at=1736190544, expires_at=None, failed_at=None, incomplete_details=None, instructions='You are a helpful assistant that generates keyword-based, Google-like user search queries that retrieve a subset of a specified list of documents.', last_error=None, max_completion_tokens=None, max_prompt_tokens=None, metadata={}, model='gpt-4o', object='thread.run', parallel_tool_calls=True, required_action=None, response_format=ResponseFormatJSONObject(type='json_object'), started_at=1736190545, status='completed', thread_id='thread_9RjUJsVMyp5WA0l5XOCyXYXb', tool_choice='auto', tools=[], truncation_strategy=TruncationStrategy(type='auto', last_messages=None), usage=Usage(completion_tokens=91, prompt_tokens=12280, total_tokens=12371, prompt_token_details={'cached_tokens': 0}), temperature=0.7, top_p=1.0, tool_resources={})
# [
#   "mathematics education identity motivation",
#   "safety behavior change BCW",
#   "landslide disaster risk management",
#   "semiotics visualization mathematics",
#   "rewilding Europe biodiversity restoration",
#   "collider physics standard model",
#   "salt tolerance rice barley",
#   "digital totalitarianism surveillance capitalism",
#   "finite difference computing PDEs",
#   "social credit system China"
# ]
# Run(id='run_ZuH6IoXZrPZRCBBKcru6QeH5', assistant_id='asst_SreO4Pk8aTxVftJmDMm2ybHM', cancelled_at=None, completed_at=1736190557, created_at=1736190553, expires_at=None, failed_at=None, incomplete_details=None, instructions='You are a helpful assistant that generates keyword-based, Google-like user search queries that retrieve a subset of a specified list of documents.', last_error=None, max_completion_tokens=None, max_prompt_tokens=None, metadata={}, model='gpt-4o', object='thread.run', parallel_tool_calls=True, required_action=None, response_format=ResponseFormatJSONObject(type='json_object'), started_at=1736190554, status='completed', thread_id='thread_tBPbLJSdLyydJNKc43OjPgB1', tool_choice='auto', tools=[], truncation_strategy=TruncationStrategy(type='auto', last_messages=None), usage=Usage(completion_tokens=94, prompt_tokens=13337, total_tokens=13431, prompt_token_details={'cached_tokens': 0}), temperature=0.7, top_p=1.0, tool_resources={})
# [
#   "Twitter research methods evaluation",
#   "X-ray contrast media properties",
#   "Hyperconnected era challenges Onlife",
#   "Blockchain DDoS network security",
#   "Iskandar Malaysia climate blueprint",
#   "Problem solving in math education",
#   "Early algebra cognitive development",
#   "Islamic bioethics medical ethics",
#   "Butterfly mimicry population dynamics",
#   "Digitalization impact on education"
# ]
# Run(id='run_NktVsfxz0LviXQEO9UWDfHd7', assistant_id='asst_SreO4Pk8aTxVftJmDMm2ybHM', cancelled_at=None, completed_at=1736190567, created_at=1736190563, expires_at=None, failed_at=None, incomplete_details=None, instructions='You are a helpful assistant that generates keyword-based, Google-like user search queries that retrieve a subset of a specified list of documents.', last_error=None, max_completion_tokens=None, max_prompt_tokens=None, metadata={}, model='gpt-4o', object='thread.run', parallel_tool_calls=True, required_action=None, response_format=ResponseFormatJSONObject(type='json_object'), started_at=1736190564, status='completed', thread_id='thread_YB4bqyd4OSsev6M2EU7AsyGk', tool_choice='auto', tools=[], truncation_strategy=TruncationStrategy(type='auto', last_messages=None), usage=Usage(completion_tokens=81, prompt_tokens=15336, total_tokens=15417, prompt_token_details={'cached_tokens': 0}), temperature=0.7, top_p=1.0, tool_resources={})
# [
#   "quantum computing teleportation",
#   "blockchain Ethereum Merge",
#   "Creative Commons licensing guide",
#   "LaTeX document structuring",
#   "artificial intelligence agents",
#   "probability mathematical statistics",
#   "object-oriented programming C++",
#   "information retrieval indexing",
#   "software engineering methodologies",
#   "eye tracking advertising"
# ]
# Run(id='run_yCwYqafaTM2febECjukGDRdQ', assistant_id='asst_SreO4Pk8aTxVftJmDMm2ybHM', cancelled_at=None, completed_at=1736190576, created_at=1736190572, expires_at=None, failed_at=None, incomplete_details=None, instructions='You are a helpful assistant that generates keyword-based, Google-like user search queries that retrieve a subset of a specified list of documents.', last_error=None, max_completion_tokens=None, max_prompt_tokens=None, metadata={}, model='gpt-4o', object='thread.run', parallel_tool_calls=True, required_action=None, response_format=ResponseFormatJSONObject(type='json_object'), started_at=1736190573, status='completed', thread_id='thread_lZ6ExKtbitlxRvvSiQw6Q6Ue', tool_choice='auto', tools=[], truncation_strategy=TruncationStrategy(type='auto', last_messages=None), usage=Usage(completion_tokens=94, prompt_tokens=12658, total_tokens=12752, prompt_token_details={'cached_tokens': 0}), temperature=0.7, top_p=1.0, tool_resources={})
# [
#   "food water security disparity",
#   "drone regulations European fragmentation",
#   "mathematics teacher identity development",
#   "risk aversion emission markets",
#   "gender roles health outcomes Europe",
#   "human-robot interaction dynamics",
#   "patient safety home care challenges",
#   "anti-deportation protests Osnabrück",
#   "numerical simulations Python introduction",
#   "autonomous mobility systems urban"
# ]
# Run(id='run_TCcTupYoWaopRfDLuMwjwzC8', assistant_id='asst_SreO4Pk8aTxVftJmDMm2ybHM', cancelled_at=None, completed_at=1736190585, created_at=1736190581, expires_at=None, failed_at=None, incomplete_details=None, instructions='You are a helpful assistant that generates keyword-based, Google-like user search queries that retrieve a subset of a specified list of documents.', last_error=None, max_completion_tokens=None, max_prompt_tokens=None, metadata={}, model='gpt-4o', object='thread.run', parallel_tool_calls=True, required_action=None, response_format=ResponseFormatJSONObject(type='json_object'), started_at=1736190582, status='completed', thread_id='thread_Zng6A3hZLL9CYcJsHU9yaykv', tool_choice='auto', tools=[], truncation_strategy=TruncationStrategy(type='auto', last_messages=None), usage=Usage(completion_tokens=90, prompt_tokens=12676, total_tokens=12766, prompt_token_details={'cached_tokens': 0}), temperature=0.7, top_p=1.0, tool_resources={})
# [
#   "Agile methodology Scrum framework",
#   "Team composition personality traits",
#   "Data Science AI ethics",
#   "Parallel entrepreneurship Africa",
#   "Environmental governance Baltic Sea",
#   "Endoprothetischen Hüftoperationen Deutschland",
#   "Saving investment Latin America",
#   "Ada Lovelace computer opera",
#   "Agricultural residue burning solutions",
#   "Production technology human-robot cooperation"
# ]
# Run(id='run_EXEVf0n6EUvHhX42W0BFcxRJ', assistant_id='asst_SreO4Pk8aTxVftJmDMm2ybHM', cancelled_at=None, completed_at=1736190593, created_at=1736190589, expires_at=None, failed_at=None, incomplete_details=None, instructions='You are a helpful assistant that generates keyword-based, Google-like user search queries that retrieve a subset of a specified list of documents.', last_error=None, max_completion_tokens=None, max_prompt_tokens=None, metadata={}, model='gpt-4o', object='thread.run', parallel_tool_calls=True, required_action=None, response_format=ResponseFormatJSONObject(type='json_object'), started_at=1736190591, status='completed', thread_id='thread_A1dseHuwTmptjpMy8NDnAgR6', tool_choice='auto', tools=[], truncation_strategy=TruncationStrategy(type='auto', last_messages=None), usage=Usage(completion_tokens=91, prompt_tokens=12780, total_tokens=12871, prompt_token_details={'cached_tokens': 0}), temperature=0.7, top_p=1.0, tool_resources={})
# [
#   "freshwater governance 21st century challenges",
#   "migration patterns EU crisis",
#   "S-BPM production industry",
#   "protected areas climate adaptation",
#   "cloud gaming latency compensation",
#   "bat conservation anthropocene",
#   "climate smart agriculture resilience",
#   "present-biased planning uncertainty",
#   "tuberculosis drug resistance",
#   "non-custodial sanctions Europe"
# ]
# Run(id='run_gMXU3d9kXv3g465UXkF6CKnu', assistant_id='asst_SreO4Pk8aTxVftJmDMm2ybHM', cancelled_at=None, completed_at=1736190603, created_at=1736190599, expires_at=None, failed_at=None, incomplete_details=None, instructions='You are a helpful assistant that generates keyword-based, Google-like user search queries that retrieve a subset of a specified list of documents.', last_error=None, max_completion_tokens=None, max_prompt_tokens=None, metadata={}, model='gpt-4o', object='thread.run', parallel_tool_calls=True, required_action=None, response_format=ResponseFormatJSONObject(type='json_object'), started_at=1736190600, status='completed', thread_id='thread_VwHXYEhUrEsxKVFxkaaPWCJY', tool_choice='auto', tools=[], truncation_strategy=TruncationStrategy(type='auto', last_messages=None), usage=Usage(completion_tokens=91, prompt_tokens=12892, total_tokens=12983, prompt_token_details={'cached_tokens': 0}), temperature=0.7, top_p=1.0, tool_resources={})
# [
#   "Arctic marine protected areas",
#   "Russian IT capitalism networks",
#   "VLBI advancements in astronomy",
#   "Digital age academic books",
#   "Venezuelan grassroots politics",
#   "Pentecostalism witchcraft dynamics",
#   "Anti-vivisection historical Britain",
#   "White-collar crime Norway",
#   "Brexit European citizenship",
#   "Food anxiety in Vietnam"
# ]
# Run(id='run_Orhk0fcGXmUROCm9pZD4RoO4', assistant_id='asst_SreO4Pk8aTxVftJmDMm2ybHM', cancelled_at=None, completed_at=1736190613, created_at=1736190607, expires_at=None, failed_at=None, incomplete_details=None, instructions='You are a helpful assistant that generates keyword-based, Google-like user search queries that retrieve a subset of a specified list of documents.', last_error=None, max_completion_tokens=None, max_prompt_tokens=None, metadata={}, model='gpt-4o', object='thread.run', parallel_tool_calls=True, required_action=None, response_format=ResponseFormatJSONObject(type='json_object'), started_at=1736190608, status='completed', thread_id='thread_IVL96wv4YdOKMSIoDd7NZzYF', tool_choice='auto', tools=[], truncation_strategy=TruncationStrategy(type='auto', last_messages=None), usage=Usage(completion_tokens=93, prompt_tokens=12780, total_tokens=12873, prompt_token_details={'cached_tokens': 0}), temperature=0.7, top_p=1.0, tool_resources={})
# [
#   "Freshwater governance 21st century",
#   "South-North migration EU crisis",
#   "Subject-Oriented BPM production",
#   "Protected areas climate adaptation",
#   "Cloud gaming latency mitigation",
#   "Bats conservation strategies Anthropocene",
#   "Climate Smart Agriculture resilience",
#   "Present-biased planning uncertainty",
#   "Tuberculosis pathogenesis treatment",
#   "Ambulante Sanktionen alternative imprisonment"
# ]
# Run(id='run_LdXhZcucox4cRFKm1BsSfGB2', assistant_id='asst_SreO4Pk8aTxVftJmDMm2ybHM', cancelled_at=None, completed_at=1736190622, created_at=1736190618, expires_at=None, failed_at=None, incomplete_details=None, instructions='You are a helpful assistant that generates keyword-based, Google-like user search queries that retrieve a subset of a specified list of documents.', last_error=None, max_completion_tokens=None, max_prompt_tokens=None, metadata={}, model='gpt-4o', object='thread.run', parallel_tool_calls=True, required_action=None, response_format=ResponseFormatJSONObject(type='json_object'), started_at=1736190619, status='completed', thread_id='thread_3DrzdMO2bCoamCdpkWINXvJb', tool_choice='auto', tools=[], truncation_strategy=TruncationStrategy(type='auto', last_messages=None), usage=Usage(completion_tokens=85, prompt_tokens=15336, total_tokens=15421, prompt_token_details={'cached_tokens': 0}), temperature=0.7, top_p=1.0, tool_resources={})
# [
#   "quantum entanglement teleportation",
#   "creative commons licensing benefits",
#   "ethereum blockchain scalability",
#   "object-oriented programming C++",
#   "quantitative risk analysis R",
#   "neural networks virtual agents",
#   "quantum supremacy applications",
#   "semantic trees logic proofs",
#   "collective intelligence digital",
#   "multiagent systems planning"
# ]
# Run(id='run_5KRKrbAAkxqxxltceya1qork', assistant_id='asst_SreO4Pk8aTxVftJmDMm2ybHM', cancelled_at=None, completed_at=1736190635, created_at=1736190630, expires_at=None, failed_at=None, incomplete_details=None, instructions='You are a helpful assistant that generates keyword-based, Google-like user search queries that retrieve a subset of a specified list of documents.', last_error=None, max_completion_tokens=None, max_prompt_tokens=None, metadata={}, model='gpt-4o', object='thread.run', parallel_tool_calls=True, required_action=None, response_format=ResponseFormatJSONObject(type='json_object'), started_at=1736190631, status='completed', thread_id='thread_Uhkx8oW4qGe316o7uRZHnLLW', tool_choice='auto', tools=[], truncation_strategy=TruncationStrategy(type='auto', last_messages=None), usage=Usage(completion_tokens=98, prompt_tokens=12670, total_tokens=12768, prompt_token_details={'cached_tokens': 0}), temperature=0.7, top_p=1.0, tool_resources={})
# [
#   "Cyber-Physical Systems emergent behaviors",
#   "U.S. Electoral College reform",
#   "Georgia economic reforms 2004-2012",
#   "NHS international volunteering benefits",
#   "Platinum Society 2050 vision",
#   "Household carbon emissions drivers",
#   "Haptic feedback in music",
#   "Jordan Valley ecological restoration",
#   "Community museums cultural identity",
#   "Sustainable peri-urban development"
# ]
# Run(id='run_Bfrh4Chg6U4RfJPAd7SI5oC1', assistant_id='asst_SreO4Pk8aTxVftJmDMm2ybHM', cancelled_at=None, completed_at=1736190645, created_at=1736190641, expires_at=None, failed_at=None, incomplete_details=None, instructions='You are a helpful assistant that generates keyword-based, Google-like user search queries that retrieve a subset of a specified list of documents.', last_error=None, max_completion_tokens=None, max_prompt_tokens=None, metadata={}, model='gpt-4o', object='thread.run', parallel_tool_calls=True, required_action=None, response_format=ResponseFormatJSONObject(type='json_object'), started_at=1736190642, status='completed', thread_id='thread_qBAGJNdu9DvHMWuRCNzfhT0p', tool_choice='auto', tools=[], truncation_strategy=TruncationStrategy(type='auto', last_messages=None), usage=Usage(completion_tokens=93, prompt_tokens=12115, total_tokens=12208, prompt_token_details={'cached_tokens': 0}), temperature=0.7, top_p=1.0, tool_resources={})
# [
#   "execution blood curative properties",
#   "posthumous harm and redemption",
#   "traditional masculinity mental health",
#   "patient-centered dementia narratives",
#   "beam emittance particle accelerators",
#   "wave energy conversion technologies",
#   "residential segregation measurement",
#   "chlorpyrifos ecological risk assessment",
#   "WiFi-based human activity recognition",
#   "transmutation technology nuclear waste"
# ]
# Run(id='run_UkhEC8K09mUQ9TVlaOrMSb6w', assistant_id='asst_SreO4Pk8aTxVftJmDMm2ybHM', cancelled_at=None, completed_at=1736190656, created_at=1736190652, expires_at=None, failed_at=None, incomplete_details=None, instructions='You are a helpful assistant that generates keyword-based, Google-like user search queries that retrieve a subset of a specified list of documents.', last_error=None, max_completion_tokens=None, max_prompt_tokens=None, metadata={}, model='gpt-4o', object='thread.run', parallel_tool_calls=True, required_action=None, response_format=ResponseFormatJSONObject(type='json_object'), started_at=1736190653, status='completed', thread_id='thread_zkHEQLTvIGN25DfoQduTtZjp', tool_choice='auto', tools=[], truncation_strategy=TruncationStrategy(type='auto', last_messages=None), usage=Usage(completion_tokens=103, prompt_tokens=11586, total_tokens=11689, prompt_token_details={'cached_tokens': 0}), temperature=0.7, top_p=1.0, tool_resources={})
# [
#   "trusted autonomy swarm intelligence",
#   "Albertine Statute Italian Unification",
#   "globalization science curricula TIMSS",
#   "Freiwilliges Engagement survey 2014",
#   "CAADP Malawi participatory policy-making",
#   "self-harm communicative social dimensions",
#   "rockburst acoustic emission monitoring",
#   "teaching tolerance globalization ICCS",
#   "asylum care nineteenth-century Ireland",
#   "fathers parental leave alone"
# ]
# Run(id='run_x2P6tzVjNpVYWnfGpYJYRZWB', assistant_id='asst_SreO4Pk8aTxVftJmDMm2ybHM', cancelled_at=None, completed_at=1736190667, created_at=1736190664, expires_at=None, failed_at=None, incomplete_details=None, instructions='You are a helpful assistant that generates keyword-based, Google-like user search queries that retrieve a subset of a specified list of documents.', last_error=None, max_completion_tokens=None, max_prompt_tokens=None, metadata={}, model='gpt-4o', object='thread.run', parallel_tool_calls=True, required_action=None, response_format=ResponseFormatJSONObject(type='json_object'), started_at=1736190665, status='completed', thread_id='thread_jYp7wPXahvdafabWJZyFxauP', tool_choice='auto', tools=[], truncation_strategy=TruncationStrategy(type='auto', last_messages=None), usage=Usage(completion_tokens=92, prompt_tokens=13337, total_tokens=13429, prompt_token_details={'cached_tokens': 0}), temperature=0.7, top_p=1.0, tool_resources={})
# [
#   "Twitter research methods analysis",
#   "X-ray contrast media pharmacology",
#   "Hyperconnected era ethical challenges",
#   "Blockchain DDoS mitigation architecture",
#   "Low Carbon Society Blueprint Malaysia",
#   "Problem solving heuristics education",
#   "Early algebra cognitive development",
#   "Life Cycle Management sustainability",
#   "Islamic bioethics medical practices",
#   "Mimetic butterfly population dynamics"
# ]
# Run(id='run_yU1aSZTlQkiXxp6Z00OJEoJs', assistant_id='asst_SreO4Pk8aTxVftJmDMm2ybHM', cancelled_at=None, completed_at=1736190676, created_at=1736190673, expires_at=None, failed_at=None, incomplete_details=None, instructions='You are a helpful assistant that generates keyword-based, Google-like user search queries that retrieve a subset of a specified list of documents.', last_error=None, max_completion_tokens=None, max_prompt_tokens=None, metadata={}, model='gpt-4o', object='thread.run', parallel_tool_calls=True, required_action=None, response_format=ResponseFormatJSONObject(type='json_object'), started_at=1736190674, status='completed', thread_id='thread_Wq28ofMTKqUclqhb3J13iGhx', tool_choice='auto', tools=[], truncation_strategy=TruncationStrategy(type='auto', last_messages=None), usage=Usage(completion_tokens=89, prompt_tokens=12658, total_tokens=12747, prompt_token_details={'cached_tokens': 0}), temperature=0.7, top_p=1.0, tool_resources={})
# [
#   "food sovereignty and globalization",
#   "European civil drone regulations",
#   "prospective math teachers identities",
#   "cap-and-trade risk aversion",
#   "family health outcomes Europe",
#   "subseafloor biosphere hydrogen",
#   "nanotechnology public engagement",
#   "shadow economy Serbia policy",
#   "Fukushima nuclear accident fish",
#   "marine litter economic impacts"
# ]
# Run(id='run_cuIaKvoN1v5PG1XFeXjN7b4D', assistant_id='asst_SreO4Pk8aTxVftJmDMm2ybHM', cancelled_at=None, completed_at=1736190690, created_at=1736190683, expires_at=None, failed_at=None, incomplete_details=None, instructions='You are a helpful assistant that generates keyword-based, Google-like user search queries that retrieve a subset of a specified list of documents.', last_error=None, max_completion_tokens=None, max_prompt_tokens=None, metadata={}, model='gpt-4o', object='thread.run', parallel_tool_calls=True, required_action=None, response_format=ResponseFormatJSONObject(type='json_object'), started_at=1736190684, status='completed', thread_id='thread_2N3Fv4e8w6wbxtX2kg2hj1Hj', tool_choice='auto', tools=[], truncation_strategy=TruncationStrategy(type='auto', last_messages=None), usage=Usage(completion_tokens=95, prompt_tokens=12892, total_tokens=12987, prompt_token_details={'cached_tokens': 0}), temperature=0.7, top_p=1.0, tool_resources={})
# [
#   "marine protected areas Arctic",
#   "Russian IT capitalism evolution",
#   "VLBI radio interferometry techniques",
#   "Open Access academic books",
#   "microfinance European convergence regions",
#   "curriculum reform European Schools",
#   "Venezuela grassroots oil politics",
#   "Pentecostalism witchcraft spiritual warfare",
#   "anti-vivisection British social history",
#   "white-collar crime Norway"
# ]
# Run(id='run_9NUmmqslguh7nBPFsh5yPDLJ', assistant_id='asst_SreO4Pk8aTxVftJmDMm2ybHM', cancelled_at=None, completed_at=1736190702, created_at=1736190695, expires_at=None, failed_at=None, incomplete_details=None, instructions='You are a helpful assistant that generates keyword-based, Google-like user search queries that retrieve a subset of a specified list of documents.', last_error=None, max_completion_tokens=None, max_prompt_tokens=None, metadata={}, model='gpt-4o', object='thread.run', parallel_tool_calls=True, required_action=None, response_format=ResponseFormatJSONObject(type='json_object'), started_at=1736190700, status='completed', thread_id='thread_WdL1KPzd99qj5pjD70ZFg3rn', tool_choice='auto', tools=[], truncation_strategy=TruncationStrategy(type='auto', last_messages=None), usage=Usage(completion_tokens=92, prompt_tokens=12280, total_tokens=12372, prompt_token_details={'cached_tokens': 0}), temperature=0.7, top_p=1.0, tool_resources={})
# [
#   "mathematics education affect motivation",
#   "safety professional skills embedding",
#   "migrant workers opinion expression",
#   "landslide risk management Sendai",
#   "adult learners lifelong mathematics",
#   "quantum optics communication technology",
#   "rewilding biodiversity farmland Europe",
#   "social credit surveillance capitalism",
#   "satellite data environmental policy",
#   "aquaculture wind farm co-location"
# ]
# Run(id='run_IRzjW3ek17mQtP9NW9d3g0cx', assistant_id='asst_SreO4Pk8aTxVftJmDMm2ybHM', cancelled_at=None, completed_at=1736190711, created_at=1736190707, expires_at=None, failed_at=None, incomplete_details=None, instructions='You are a helpful assistant that generates keyword-based, Google-like user search queries that retrieve a subset of a specified list of documents.', last_error=None, max_completion_tokens=None, max_prompt_tokens=None, metadata={}, model='gpt-4o', object='thread.run', parallel_tool_calls=True, required_action=None, response_format=ResponseFormatJSONObject(type='json_object'), started_at=1736190708, status='completed', thread_id='thread_nwxuPZGzFSJ0R18yuQQ4MSzE', tool_choice='auto', tools=[], truncation_strategy=TruncationStrategy(type='auto', last_messages=None), usage=Usage(completion_tokens=90, prompt_tokens=12676, total_tokens=12766, prompt_token_details={'cached_tokens': 0}), temperature=0.7, top_p=1.0, tool_resources={})
# [
#   "Agile methodology Scrum principles",
#   "Myers-Briggs team composition",
#   "Data Science AI ethics",
#   "Parallel entrepreneurship Africa",
#   "Baltic Sea environmental governance",
#   "Endoprothesenversorgung Deutschland",
#   "Latin America saving investment",
#   "Ada Lovelace opera narrative",
#   "Socioeconomic residue burning Punjab",
#   "Human-robot cooperation manufacturing"
# ]
# Run(id='run_PxUzs8QyjWTvQbGsCoNJvf3g', assistant_id='asst_SreO4Pk8aTxVftJmDMm2ybHM', cancelled_at=None, completed_at=1736190725, created_at=1736190719, expires_at=None, failed_at=None, incomplete_details=None, instructions='You are a helpful assistant that generates keyword-based, Google-like user search queries that retrieve a subset of a specified list of documents.', last_error=None, max_completion_tokens=None, max_prompt_tokens=None, metadata={}, model='gpt-4o', object='thread.run', parallel_tool_calls=True, required_action=None, response_format=ResponseFormatJSONObject(type='json_object'), started_at=1736190722, status='completed', thread_id='thread_nNGXUsZoIe3TvwQX0ISRHQ0N', tool_choice='auto', tools=[], truncation_strategy=TruncationStrategy(type='auto', last_messages=None), usage=Usage(completion_tokens=97, prompt_tokens=13337, total_tokens=13434, prompt_token_details={'cached_tokens': 0}), temperature=0.7, top_p=1.0, tool_resources={})
# [
#   "Twitter research methodologies evaluation",
#   "X-ray contrast media safety",
#   "Distributed epistemic responsibility Onlife",
#   "Blockchain DDoS mitigation architecture",
#   "Low Carbon Society Blueprint Malaysia",
#   "Problem solving in mathematics education",
#   "Congenital heart defects ETS-1",
#   "Nature-based solutions urban adaptation",
#   "Trust in electronic equipment vendors",
#   "Microfinance 3.0 sustainable practices"
# ]
# Run(id='run_SDd0UgXH5V5PGm6ZLVVL1Svl', assistant_id='asst_SreO4Pk8aTxVftJmDMm2ybHM', cancelled_at=None, completed_at=1736190738, created_at=1736190734, expires_at=None, failed_at=None, incomplete_details=None, instructions='You are a helpful assistant that generates keyword-based, Google-like user search queries that retrieve a subset of a specified list of documents.', last_error=None, max_completion_tokens=None, max_prompt_tokens=None, metadata={}, model='gpt-4o', object='thread.run', parallel_tool_calls=True, required_action=None, response_format=ResponseFormatJSONObject(type='json_object'), started_at=1736190735, status='completed', thread_id='thread_xiv6LKk2Y0GI1gOok0IhQTzc', tool_choice='auto', tools=[], truncation_strategy=TruncationStrategy(type='auto', last_messages=None), usage=Usage(completion_tokens=87, prompt_tokens=12780, total_tokens=12867, prompt_token_details={'cached_tokens': 0}), temperature=0.7, top_p=1.0, tool_resources={})
# [
#   "Freshwater governance challenges",
#   "South-North EU migration",
#   "Subject-Oriented BPM production",
#   "Central Europe climate adaptation",
#   "Cloud gaming latency solutions",
#   "Bat conservation Anthropocene",
#   "Climate Smart Agriculture strategies",
#   "Behavioral economics present bias",
#   "Tuberculosis treatment advancements",
#   "Non-custodial sanctions Europe"
# ]
# Run(id='run_QX1OpfazPg3jlCNrRUNJsATX', assistant_id='asst_SreO4Pk8aTxVftJmDMm2ybHM', cancelled_at=None, completed_at=1736190752, created_at=1736190744, expires_at=None, failed_at=None, incomplete_details=None, instructions='You are a helpful assistant that generates keyword-based, Google-like user search queries that retrieve a subset of a specified list of documents.', last_error=None, max_completion_tokens=None, max_prompt_tokens=None, metadata={}, model='gpt-4o', object='thread.run', parallel_tool_calls=True, required_action=None, response_format=ResponseFormatJSONObject(type='json_object'), started_at=1736190745, status='completed', thread_id='thread_60XhZ5gaT66BcNDzFbEzYZfJ', tool_choice='auto', tools=[], truncation_strategy=TruncationStrategy(type='auto', last_messages=None), usage=Usage(completion_tokens=87, prompt_tokens=12676, total_tokens=12763, prompt_token_details={'cached_tokens': 0}), temperature=0.7, top_p=1.0, tool_resources={})
# [
#   "Agile methodology Scrum framework",
#   "Myers-Briggs team composition",
#   "Data Science AI systems",
#   "Parallel entrepreneurship Africa",
#   "Baltic Sea environmental governance",
#   "Endoprothesenversorgung Deutschland",
#   "Latin America saving rates",
#   "Ada Lovelace computing history",
#   "Punjab agricultural residue burning",
#   "Additive manufacturing technology"
# ]
# Run(id='run_cUPtwtscTTl4PWlSRXDvwGsD', assistant_id='asst_SreO4Pk8aTxVftJmDMm2ybHM', cancelled_at=None, completed_at=1736190760, created_at=1736190756, expires_at=None, failed_at=None, incomplete_details=None, instructions='You are a helpful assistant that generates keyword-based, Google-like user search queries that retrieve a subset of a specified list of documents.', last_error=None, max_completion_tokens=None, max_prompt_tokens=None, metadata={}, model='gpt-4o', object='thread.run', parallel_tool_calls=True, required_action=None, response_format=ResponseFormatJSONObject(type='json_object'), started_at=1736190757, status='completed', thread_id='thread_4NoLEyHiRkpIeooPoF1H5CmP', tool_choice='auto', tools=[], truncation_strategy=TruncationStrategy(type='auto', last_messages=None), usage=Usage(completion_tokens=91, prompt_tokens=12658, total_tokens=12749, prompt_token_details={'cached_tokens': 0}), temperature=0.7, top_p=1.0, tool_resources={})
# [
#   "food sovereignty globalization nutrition",
#   "European drone regulations ethics",
#   "Prospective math teacher identities",
#   "cap-and-trade risk aversion",
#   "gender roles health Europe",
#   "autonomous urban mobility AMoD",
#   "hydrothermal hydrogen microbial ecosystems",
#   "social innovations Malmö Sweden",
#   "marine litter economic impact",
#   "quantum mechanics determinism chaos"
# ]
# Run(id='run_QkRyI2IvOegJkR89yGSRdSHx', assistant_id='asst_SreO4Pk8aTxVftJmDMm2ybHM', cancelled_at=None, completed_at=1736190771, created_at=1736190766, expires_at=None, failed_at=None, incomplete_details=None, instructions='You are a helpful assistant that generates keyword-based, Google-like user search queries that retrieve a subset of a specified list of documents.', last_error=None, max_completion_tokens=None, max_prompt_tokens=None, metadata={}, model='gpt-4o', object='thread.run', parallel_tool_calls=True, required_action=None, response_format=ResponseFormatJSONObject(type='json_object'), started_at=1736190768, status='completed', thread_id='thread_1SWFnQ5utkqBcPTXKA7fLGBC', tool_choice='auto', tools=[], truncation_strategy=TruncationStrategy(type='auto', last_messages=None), usage=Usage(completion_tokens=86, prompt_tokens=15336, total_tokens=15422, prompt_token_details={'cached_tokens': 0}), temperature=0.7, top_p=1.0, tool_resources={})
# [
#   "quantum computing key algorithms",
#   "creative commons licensing guide",
#   "blockchain technology Ethereum Merge",
#   "AI cognitive science agents",
#   "object-oriented programming C++",
#   "risk analysis decision trees",
#   "LaTeX structure basic commands",
#   "SQL language database systems",
#   "eye tracking consumer behavior",
#   "collective intelligence digital knowledge"
# ]
# ...
# [
#   "Arctic marine protected areas",
#   "Russian IT capitalism networks",
#   "VLBI radio astronomy techniques",
#   "Digital academic book evolution",
#   "Social microcredit urban regeneration",
#   "Bolivarian grassroots politics Venezuela",
#   "Pentecostalism witchcraft spiritual warfare",
#   "Anti-vivisection movement Britain",
#   "White-collar crime Norway",
#   "Food anxiety Vietnam modernization"
# ]
# Run(id='run_BZIVa0qcTmPc5rytIoVmmpom', assistant_id='asst_SreO4Pk8aTxVftJmDMm2ybHM', cancelled_at=None, completed_at=1736190827, created_at=1736190823, expires_at=None, failed_at=None, incomplete_details=None, instructions='You are a helpful assistant that generates keyword-based, Google-like user search queries that retrieve a subset of a specified list of documents.', last_error=None, max_completion_tokens=None, max_prompt_tokens=None, metadata={}, model='gpt-4o', object='thread.run', parallel_tool_calls=True, required_action=None, response_format=ResponseFormatJSONObject(type='json_object'), started_at=1736190825, status='completed', thread_id='thread_zaFq554Vg1s2rkSIzaW1MUn9', tool_choice='auto', tools=[], truncation_strategy=TruncationStrategy(type='auto', last_messages=None), usage=Usage(completion_tokens=105, prompt_tokens=12280, total_tokens=12385, prompt_token_details={'cached_tokens': 0}), temperature=0.7, top_p=1.0, tool_resources={})
# [
#   "mathematics education self-efficacy beliefs",
#   "Safety-II resilience industrial safety",
#   "landslide risk management Sendai Framework",
#   "quantum optics communication technologies",
#   "grain boundary engineering alumina ceramics",
#   "rewilding ecological conservation Europe",
#   "North Sea climate change assessment",
#   "surveillance capitalism privacy autonomy",
#   "CRISPR-Cas9 Duchenne muscular dystrophy",
#   "cosmic ray neutron sensing agriculture"
# ]
# Run(id='run_1PuyPjdRMMY65ZL7QfOeBMDv', assistant_id='asst_SreO4Pk8aTxVftJmDMm2ybHM', cancelled_at=None, completed_at=1736190838, created_at=1736190832, expires_at=None, failed_at=None, incomplete_details=None, instructions='You are a helpful assistant that generates keyword-based, Google-like user search queries that retrieve a subset of a specified list of documents.', last_error=None, max_completion_tokens=None, max_prompt_tokens=None, metadata={}, model='gpt-4o', object='thread.run', parallel_tool_calls=True, required_action=None, response_format=ResponseFormatJSONObject(type='json_object'), started_at=1736190834, status='completed', thread_id='thread_NKxjaU9sZsp4K3zvEcV2VQh6', tool_choice='auto', tools=[], truncation_strategy=TruncationStrategy(type='auto', last_messages=None), usage=Usage(completion_tokens=93, prompt_tokens=12280, total_tokens=12373, prompt_token_details={'cached_tokens': 0}), temperature=0.7, top_p=1.0, tool_resources={})
# [
#   "mathematics education self-efficacy beliefs",
#   "embedding safety professional skills",
#   "opinion expression migrant workers",
#   "landslide risk disaster management",
#   "adult learners lifelong mathematics",
#   "quantum communication structured light",
#   "semiotics in mathematics education",
#   "rewilding ecological benefits Europe",
#   "satellite Earth observations policy",
#   "ion channels Markov models"
# ]
# Run(id='run_bhChz7Y36KBtZ8jirOqcNH6E', assistant_id='asst_SreO4Pk8aTxVftJmDMm2ybHM', cancelled_at=None, completed_at=1736190851, created_at=1736190845, expires_at=None, failed_at=None, incomplete_details=None, instructions='You are a helpful assistant that generates keyword-based, Google-like user search queries that retrieve a subset of a specified list of documents.', last_error=None, max_completion_tokens=None, max_prompt_tokens=None, metadata={}, model='gpt-4o', object='thread.run', parallel_tool_calls=True, required_action=None, response_format=ResponseFormatJSONObject(type='json_object'), started_at=1736190847, status='completed', thread_id='thread_RPUGJomkAmlD8034F01aN14M', tool_choice='auto', tools=[], truncation_strategy=TruncationStrategy(type='auto', last_messages=None), usage=Usage(completion_tokens=92, prompt_tokens=12670, total_tokens=12762, prompt_token_details={'cached_tokens': 0}), temperature=0.7, top_p=1.0, tool_resources={})
# [
#   "Cyber-Physical Systems AMADEOS",
#   "Electoral College reform U.S.",
#   "Healthcare professional volunteering NHS",
#   "Renewable energy Platinum Society",
#   "Jordan River ecological restoration",
#   "Musical haptic feedback technology",
#   "Asian philanthropy impact investing",
#   "Hybrid warfare Yugoslavia Ukraine",
#   "Memory identity conflict transformation",
#   "Generational gender identity evolution"
# ]
# Run(id='run_rBzP1AIplTQGLL5f6uYdeRQ5', assistant_id='asst_SreO4Pk8aTxVftJmDMm2ybHM', cancelled_at=None, completed_at=1736190863, created_at=1736190858, expires_at=None, failed_at=None, incomplete_details=None, instructions='You are a helpful assistant that generates keyword-based, Google-like user search queries that retrieve a subset of a specified list of documents.', last_error=None, max_completion_tokens=None, max_prompt_tokens=None, metadata={}, model='gpt-4o', object='thread.run', parallel_tool_calls=True, required_action=None, response_format=ResponseFormatJSONObject(type='json_object'), started_at=1736190859, status='completed', thread_id='thread_TOMHJePmWEiZHixLjoHbfi5g', tool_choice='auto', tools=[], truncation_strategy=TruncationStrategy(type='auto', last_messages=None), usage=Usage(completion_tokens=87, prompt_tokens=12892, total_tokens=12979, prompt_token_details={'cached_tokens': 0}), temperature=0.7, top_p=1.0, tool_resources={})
# [
#   "marine protected areas Arctic",
#   "Russian IT capitalism blat",
#   "VLBI radio astronomy techniques",
#   "future academic book digital",
#   "social microcredit urban regeneration",
#   "EU citizenship rights Brexit",
#   "food anxiety Vietnam modernization",
#   "chemical warfare Japan WWII",
#   "railway verges biodiversity conservation",
#   "entrepreneurial self-compassion failure"
# ]
# Run(id='run_v6uUyt941rdHckmGS0fzq7aN', assistant_id='asst_SreO4Pk8aTxVftJmDMm2ybHM', cancelled_at=None, completed_at=1736190874, created_at=1736190870, expires_at=None, failed_at=None, incomplete_details=None, instructions='You are a helpful assistant that generates keyword-based, Google-like user search queries that retrieve a subset of a specified list of documents.', last_error=None, max_completion_tokens=None, max_prompt_tokens=None, metadata={}, model='gpt-4o', object='thread.run', parallel_tool_calls=True, required_action=None, response_format=ResponseFormatJSONObject(type='json_object'), started_at=1736190871, status='completed', thread_id='thread_pVebwdwGNtfaUZ34bhL0kvbd', tool_choice='auto', tools=[], truncation_strategy=TruncationStrategy(type='auto', last_messages=None), usage=Usage(completion_tokens=103, prompt_tokens=12658, total_tokens=12761, prompt_token_details={'cached_tokens': 0}), temperature=0.7, top_p=1.0, tool_resources={})
# [
#   "autonomous mobility-on-demand systems",
#   "food and water security challenges",
#   "European civil drone regulations",
#   "impact of hydropeaking on ecosystems",
#   "role of hydrogen in hydrothermal systems",
#   "subseafloor biosphere and serpentinization",
#   "McEliece cryptosystem enhancements",
#   "public engagement with nanotechnology",
#   "demographic shifts and health outcomes",
#   "FRAND commitments and SEPs"
# ]
# Run(id='run_tLu7xlhxVsjBZltY5yraToZv', assistant_id='asst_SreO4Pk8aTxVftJmDMm2ybHM', cancelled_at=None, completed_at=1736190883, created_at=1736190879, expires_at=None, failed_at=None, incomplete_details=None, instructions='You are a helpful assistant that generates keyword-based, Google-like user search queries that retrieve a subset of a specified list of documents.', last_error=None, max_completion_tokens=None, max_prompt_tokens=None, metadata={}, model='gpt-4o', object='thread.run', parallel_tool_calls=True, required_action=None, response_format=ResponseFormatJSONObject(type='json_object'), started_at=1736190880, status='completed', thread_id='thread_fKN9vb3IH0ZprL6aV9H6ZQXs', tool_choice='auto', tools=[], truncation_strategy=TruncationStrategy(type='auto', last_messages=None), usage=Usage(completion_tokens=94, prompt_tokens=12115, total_tokens=12209, prompt_token_details={'cached_tokens': 0}), temperature=0.7, top_p=1.0, tool_resources={})
# [
#   "execution blood curative practices",
#   "posthumous punishment and redemption",
#   "male mental health disorders Britain",
#   "Alzheimer's patient narratives",
#   "wave energy conversion technology",
#   "residential segregation measurement",
#   "biodiversity observation citizen science",
#   "chlorpyrifos ecological risk assessment",
#   "WiFi-based human activity recognition",
#   "robot-assisted laser surgery models"
# ]
# Run(id='run_MfthdKDu4ifevdx3yScDmwhr', assistant_id='asst_SreO4Pk8aTxVftJmDMm2ybHM', cancelled_at=None, completed_at=1736190893, created_at=1736190889, expires_at=None, failed_at=None, incomplete_details=None, instructions='You are a helpful assistant that generates keyword-based, Google-like user search queries that retrieve a subset of a specified list of documents.', last_error=None, max_completion_tokens=None, max_prompt_tokens=None, metadata={}, model='gpt-4o', object='thread.run', parallel_tool_calls=True, required_action=None, response_format=ResponseFormatJSONObject(type='json_object'), started_at=1736190890, status='completed', thread_id='thread_GmSRs4cYUED6wUrh2I9xVqlx', tool_choice='auto', tools=[], truncation_strategy=TruncationStrategy(type='auto', last_messages=None), usage=Usage(completion_tokens=88, prompt_tokens=12676, total_tokens=12764, prompt_token_details={'cached_tokens': 0}), temperature=0.7, top_p=1.0, tool_resources={})
# [
#   "Agile methodology Scrum framework",
#   "Myers-Briggs team composition",
#   "Data Science ethical implications",
#   "Baltic Sea environmental governance",
#   "Parallel entrepreneurship Africa",
#   "Climate change Germany hydrology",
#   "Nuclear resilience Fukushima",
#   "Ranavirus amphibian immune response",
#   "Bioeconomy sustainable practices",
#   "Mobile technology Papua New Guinea"
# ]
# Run(id='run_rHW6rSTKo10GFJYSVhKtez9L', assistant_id='asst_SreO4Pk8aTxVftJmDMm2ybHM', cancelled_at=None, completed_at=1736190912, created_at=1736190905, expires_at=None, failed_at=None, incomplete_details=None, instructions='You are a helpful assistant that generates keyword-based, Google-like user search queries that retrieve a subset of a specified list of documents.', last_error=None, max_completion_tokens=None, max_prompt_tokens=None, metadata={}, model='gpt-4o', object='thread.run', parallel_tool_calls=True, required_action=None, response_format=ResponseFormatJSONObject(type='json_object'), started_at=1736190907, status='completed', thread_id='thread_vK9TkfyndeuB7mkHx1ZWlhs8', tool_choice='auto', tools=[], truncation_strategy=TruncationStrategy(type='auto', last_messages=None), usage=Usage(completion_tokens=93, prompt_tokens=11586, total_tokens=11679, prompt_token_details={'cached_tokens': 0}), temperature=0.7, top_p=1.0, tool_resources={})
# [
#   "autonomous systems trustworthiness challenges",
#   "constitutional norms Italian unification",
#   "globalization science curricula TIMSS",
#   "political economy Malawi agriculture",
#   "history self-harm Britain",
#   "force-feeding ethics prisons",
#   "migration education Thailand challenges",
#   "fatherhood parental leave impact",
#   "radiation Fukushima nuclear accident",
#   "ocean-atmosphere greenhouse gases"
# ]
# Run(id='run_lpG1tcaNmqwpJTne591lleXW', assistant_id='asst_SreO4Pk8aTxVftJmDMm2ybHM', cancelled_at=None, completed_at=1736190922, created_at=1736190917, expires_at=None, failed_at=None, incomplete_details=None, instructions='You are a helpful assistant that generates keyword-based, Google-like user search queries that retrieve a subset of a specified list of documents.', last_error=None, max_completion_tokens=None, max_prompt_tokens=None, metadata={}, model='gpt-4o', object='thread.run', parallel_tool_calls=True, required_action=None, response_format=ResponseFormatJSONObject(type='json_object'), started_at=1736190920, status='completed', thread_id='thread_kasxBlrTnk7XplGfraBR0lDu', tool_choice='auto', tools=[], truncation_strategy=TruncationStrategy(type='auto', last_messages=None), usage=Usage(completion_tokens=93, prompt_tokens=12780, total_tokens=12873, prompt_token_details={'cached_tokens': 0}), temperature=0.7, top_p=1.0, tool_resources={})
# [
#   "freshwater governance innovative approaches",
#   "South-North EU migration crisis",
#   "S-BPM production industry challenges",
#   "climate change protected areas",
#   "lag compensation cloud gaming",
#   "bats conservation Anthropocene",
#   "Climate Smart Agriculture strategies",
#   "intra-EU migration socio-economic",
#   "autonomous control Internet services",
#   "neurosciences interdisciplinary collaboration"
# ]
# Run(id='run_WJ7Yd40PbkjiYoYQJ8R0QMiY', assistant_id='asst_SreO4Pk8aTxVftJmDMm2ybHM', cancelled_at=None, completed_at=1736190934, created_at=1736190927, expires_at=None, failed_at=None, incomplete_details=None, instructions='You are a helpful assistant that generates keyword-based, Google-like user search queries that retrieve a subset of a specified list of documents.', last_error=None, max_completion_tokens=None, max_prompt_tokens=None, metadata={}, model='gpt-4o', object='thread.run', parallel_tool_calls=True, required_action=None, response_format=ResponseFormatJSONObject(type='json_object'), started_at=1736190928, status='completed', thread_id='thread_ek7nf4kFWCQrg91FKBVEYcrD', tool_choice='auto', tools=[], truncation_strategy=TruncationStrategy(type='auto', last_messages=None), usage=Usage(completion_tokens=85, prompt_tokens=15336, total_tokens=15421, prompt_token_details={'cached_tokens': 0}), temperature=0.7, top_p=1.0, tool_resources={})
# [
#   "quantum computing algorithms introduction",
#   "Creative Commons licensing guide",
#   "blockchain technology Bitcoin Ethereum",
#   "object-oriented programming C++",
#   "multiagent systems cognitive agents",
#   "use cases UML software",
#   "Semantic resolution in logic",
#   "risk analysis in R",
#   "synchronization concurrent programming",
#   "functional programming in R"
# ]
# Run(id='run_eBAbRaX7mKGjeyreoVEfB5sK', assistant_id='asst_SreO4Pk8aTxVftJmDMm2ybHM', cancelled_at=None, completed_at=1736190945, created_at=1736190939, expires_at=None, failed_at=None, incomplete_details=None, instructions='You are a helpful assistant that generates keyword-based, Google-like user search queries that retrieve a subset of a specified list of documents.', last_error=None, max_completion_tokens=None, max_prompt_tokens=None, metadata={}, model='gpt-4o', object='thread.run', parallel_tool_calls=True, required_action=None, response_format=ResponseFormatJSONObject(type='json_object'), started_at=1736190940, status='completed', thread_id='thread_CjBBj3XDD8EXgGBHhnq3X78z', tool_choice='auto', tools=[], truncation_strategy=TruncationStrategy(type='auto', last_messages=None), usage=Usage(completion_tokens=93, prompt_tokens=13337, total_tokens=13430, prompt_token_details={'cached_tokens': 0}), temperature=0.7, top_p=1.0, tool_resources={})
# [
#   "Twitter research methods analysis",
#   "X-ray contrast media safety",
#   "Hyperconnected era epistemic responsibility",
#   "Blockchain DDoS mitigation architecture",
#   "Iskandar Malaysia sustainability blueprint",
#   "Early algebra cognitive development",
#   "Islamic bioethics medical ethics",
#   "Butterfly mimicry population dynamics",
#   "Digitalization smart grids energy",
#   "Life cycle management sustainability"
# ]

# %%
# Save generated queries to a json file

with open(queries_filename, 'w') as f:
    json.dump(queries, f, indent=2, ensure_ascii=False)

# %%
# Delete the assistant

res = client.beta.assistants.delete(assistant.id)
print(res)
# Out:
# AssistantDeleted(id='asst_SreO4Pk8aTxVftJmDMm2ybHM', deleted=True, object='assistant.deleted')
